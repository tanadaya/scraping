# %%
# Vessels 一括エクスポート用のモジュールを読み込みます
import os
import sys
from pathlib import Path
PROJECT_ROOT = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "tools").is_dir() and (path / "vessel").is_dir()
)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
os.chdir(PROJECT_ROOT)

from tools.scrapers import vessels as ssv

# %%
# 取得対象の船種フィルタを設定します
# AVAILABLE_FILTER_LABELS から必要なものだけ FILTER_LABELS に並べてください。
AVAILABLE_FILTER_LABELS = list(ssv.DEFAULT_VESSELS_FILTER_LABELS)

# 必要な船種だけを指定します。複数指定も可能です。
FILTER_LABELS = [
    "Container",
    "Ro-Ro",
    "Chemical tanker",
    "Oil tanker",
    "Liquefied gas tanker",
    "Other liquids tankers",
    "Bulk Carrier",
]

FILTER_LABELS

# %%
# 出力設定をここで調整します
# SeaSearcher login account. Set both values, or leave both as None to use environment variables.
LOGIN_CONFIG = {
    "login_user": None,  # Login user
    "login_password": None,  # Login password
}

EXPORT_CONFIG = {
    "out_dir": "vessel",
    "login_user": LOGIN_CONFIG["login_user"],
    "login_password": LOGIN_CONFIG["login_password"],
    "file_label": "20260817",
    "encoding": "utf-8-sig",
    "headless": False,
    "keep_raw_pages": False,
    "overwrite": True,
    "log_steps": True,
}

EXPORT_CONFIG

# %%
# 船種ごとに全ページをダウンロードして結合します
results = ssv.export_vessels_filters(FILTER_LABELS, EXPORT_CONFIG)

results
